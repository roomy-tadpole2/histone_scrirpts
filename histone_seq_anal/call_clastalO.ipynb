# %%
import subprocess

def call_clustalo_omega(input_fasta, output_fasta):

    command = ["clustalo", "-i", input_fasta, "-o", output_fasta, "--outfmt", "fasta", '--force']
    try:
        res = subprocess.run(command, check=True)
    except Exception as E:
        display(E)
        print(f"command = {command}")
    else:
        print(f"return code = {res.returncode}")

# %%
call_clustalo_omega("data\\H2A\\H2A.fasta", "data\\H2A\\H2A_result.fasta")
# Out:
# return code = 0

# %%
from plot import plot
plot(input_file_path="data\\H2A\\H2A_result.fasta",
     output_file_path="data\\H2A\\H2A_result.pdf", y_zip=0.74)
# Out:
# num seq = 13
# Current y-tick spacing: 0.74

# %%
call_clustalo_omega("data\\H2B\\H2B.fasta", "data\\H2B\\H2B_result.fasta")
# Out:
# return code = 0

# %%
plot(input_file_path="data\\H2B\\H2B_result.fasta",
     output_file_path="data\\H2B\\H2B_result.pdf", y_zip=0.74)
# Out:
# num seq = 11
# Current y-tick spacing: 0.74

# %%
call_clustalo_omega("data\\H3\\H3.fasta", "data\\H3\\H3_result.fasta")
# Out:
# return code = 0

# %%
plot(input_file_path="data\\H3\\H3_result.fasta",
     output_file_path="data\\H3\\H3_result.pdf", y_zip=0.74)
# Out:
# num seq = 14
# Current y-tick spacing: 0.74

# %%
call_clustalo_omega("data\\all\\all.fasta", "data\\all\\all_result.fasta")
# Out:
# return code = 0

# %%
plot(input_file_path="data\\all\\all_result.fasta",
     output_file_path="data\\all\\all_result.pdf", y_zip=0.74)
# Out:
# num seq = 38
# Current y-tick spacing: 0.74
